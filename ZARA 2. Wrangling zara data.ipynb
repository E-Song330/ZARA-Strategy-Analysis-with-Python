# %%
import pandas as pd
zara = pd.read_csv('./zara.csv')

# %%
zara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       328 non-null    object
#  1   Chain      328 non-null    object
#  2   Street     328 non-null    object
#  3   City       328 non-null    object
#  4   Region     328 non-null    object
#  5   Section    328 non-null    object
#  6   C_c        203 non-null    object
#  7   Latitude   328 non-null    float64
#  8   Longitude  328 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 23.2+ KB

# %%
# sort data by brand


grouped = zara.groupby('Chain')


for name, group in grouped:
    print(name)
    print(group)
# Out:
# kiddy's class
#                                        Name          Chain  \
# 82             ('rib-rodriguez murias_kc',)  kiddy's class
# 83                     ('utr-almazara_kc',)  kiddy's class
# 84                    ('val-de españa_kc',)  kiddy's class
# 85                 ('mon-de andalucia_kc',)  kiddy's class
# 86              ('vil-de la parellada_kc',)  kiddy's class
# 87                     ('bcn-de sants_kc',)  kiddy's class
# 88                 ('c.real-el parque_kc',)  kiddy's class
# 89                  ('xat-plaza mayor_kc',)  kiddy's class
# 90             ('alc.guad-los alcores_kc',)  kiddy's class
# 91              ('tor-costasol centro_kc',)  kiddy's class
# 92                  ('ant-la veronica_kc',)  kiddy's class
# 93                 ('mana-rector rubi_kc',)  kiddy's class
# 94               ('mol.seg-vega plaza_kc',)  kiddy's class
# 95                  ('vic-santa clara_kc',)  kiddy's class
# 97                   ('mad-juan muñoz_kc',)  kiddy's class
# ...

# %%
kiddy = grouped.get_group("kiddy's class")

# %%
za = grouped.get_group("zara")
za = za[za.Section != ', , Niño']
za.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 0 to 326
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       184 non-null    object
#  1   Chain      184 non-null    object
#  2   Street     184 non-null    object
#  3   City       184 non-null    object
#  4   Region     184 non-null    object
#  5   Section    184 non-null    object
#  6   C_c        113 non-null    object
#  7   Latitude   184 non-null    float64
#  8   Longitude  184 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 14.4+ KB

# %%
lefties = grouped.get_group("lefties")

# %%
za = real_za.append(kiddy)
za = za.append(lefties)

reza = za.drop_duplicates(['Name'], keep = 'first', ignore_index = True)

# %%
grouped2 = reza.groupby('Chain')


for name, group in grouped2:
    print(name)
    print(group)
# Out:
# kiddy's class
#                                        Name          Chain  \
# 186            ('rib-rodriguez murias_kc',)  kiddy's class
# 187                    ('utr-almazara_kc',)  kiddy's class
# 188                   ('val-de españa_kc',)  kiddy's class
# 189                ('mon-de andalucia_kc',)  kiddy's class
# 190             ('vil-de la parellada_kc',)  kiddy's class
# 191                    ('bcn-de sants_kc',)  kiddy's class
# 192                ('c.real-el parque_kc',)  kiddy's class
# 193                 ('xat-plaza mayor_kc',)  kiddy's class
# 194            ('alc.guad-los alcores_kc',)  kiddy's class
# 195             ('tor-costasol centro_kc',)  kiddy's class
# 196                 ('ant-la veronica_kc',)  kiddy's class
# 197                ('mana-rector rubi_kc',)  kiddy's class
# 198              ('mol.seg-vega plaza_kc',)  kiddy's class
# 199                 ('vic-santa clara_kc',)  kiddy's class
# 200                  ('mad-juan muñoz_kc',)  kiddy's class
# ...

# %%
reza.to_excel('./reza.xlsx', index = False, encoding = 'latin1')

# %%
real_za.to_csv('./realza.csv', index = False)

# %%
pivot_z = reza.pivot_table(index = {'City','Region'}, values = 'Name', aggfunc = 'count')
pivot_z.head()
# Out:
#                               Name
# Region    City
# andalucía alcala de guadaira     2
#           algeciras              1
#           almeria                1
#           antequera              2
#           armilla                1
